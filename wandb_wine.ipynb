# %%
# !pip install wandb
# Out:
# Requirement already satisfied: wandb in c:\users\david\desktop\upgrade_python\mi_entorno\lib\site-packages (0.16.0)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in c:\users\david\desktop\upgrade_python\mi_entorno\lib\site-packages (from wandb) (8.1.7)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in c:\users\david\desktop\upgrade_python\mi_entorno\lib\site-packages (from wandb) (3.1.40)
# Requirement already satisfied: requests<3,>=2.0.0 in c:\users\david\desktop\upgrade_python\mi_entorno\lib\site-packages (from wandb) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in c:\users\david\desktop\upgrade_python\mi_entorno\lib\site-packages (from wandb) (5.9.6)
# Requirement already satisfied: sentry-sdk>=1.0.0 in c:\users\david\desktop\upgrade_python\mi_entorno\lib\site-packages (from wandb) (1.38.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in c:\users\david\desktop\upgrade_python\mi_entorno\lib\site-packages (from wandb) (0.4.0)
# Requirement already satisfied: PyYAML in c:\users\david\desktop\upgrade_python\mi_entorno\lib\site-packages (from wandb) (6.0.1)
# Requirement already satisfied: setproctitle in c:\users\david\desktop\upgrade_python\mi_entorno\lib\site-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in c:\users\david\desktop\upgrade_python\mi_entorno\lib\site-packages (from wandb) (65.5.0)
# Requirement already satisfied: appdirs>=1.4.3 in c:\users\david\desktop\upgrade_python\mi_entorno\lib\site-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in c:\users\david\desktop\upgrade_python\mi_entorno\lib\site-packages (from wandb) (4.21.12)
# Requirement already satisfied: colorama in c:\users\david\desktop\upgrade_python\mi_entorno\lib\site-packages (from Click!=8.0.0,>=7.1->wandb) (0.4.6)
# Requirement already satisfied: six>=1.4.0 in c:\users\david\desktop\upgrade_python\mi_entorno\lib\site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\david\desktop\upgrade_python\mi_entorno\lib\site-packages (from GitPython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\david\desktop\upgrade_python\mi_entorno\lib\site-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\david\desktop\upgrade_python\mi_entorno\lib\site-packages (from requests<3,>=2.0.0->wandb) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\david\desktop\upgrade_python\mi_entorno\lib\site-packages (from requests<3,>=2.0.0->wandb) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\david\desktop\upgrade_python\mi_entorno\lib\site-packages (from requests<3,>=2.0.0->wandb) (2023.11.17)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\david\desktop\upgrade_python\mi_entorno\lib\site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\david\desktop\upgrade_python\mi_entorno\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\david\desktop\upgrade_python\mi_entorno\lib\site-packages)

# %%
import numpy as np
import wandb
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score
from sklearn.preprocessing import label_binarize

# %%
#arrmar informe wandb 
#crear repo 
#compartir repo

# %%
wine = load_wine()

# %%
x, y = wine.data, wine.target

# %%
#Es lo mismo que arriba
# x = wine.data
# y = wine.target

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=357)

# %%
hyperparameters = {
    "learning_rates" : [0.013, 0.2, 0.3, 0.6],
    "max_depths" : [3,4,5,6],
    "n_estimator" : [43, 100, 150],
    "loss_functions" : ["deviance"],
    "subsamples" : [0.8, 1.0], 
    "min_samples_splits" : [2,4],
    "min_samples_leaf" : [1,2]
}

# %%
for lr in hyperparameters["learning_rates"]:
    for max_depth in hyperparameters["max_depths"]:
        for n_estimator in hyperparameters["n_estimator"]:
            for loss_function in hyperparameters["loss_functions"]:
                for subsample in hyperparameters["subsamples"]:
                    for min_samples_split in hyperparameters["min_samples_splits"]:
                        for min_samples_leaf in hyperparameters ["min_samples_leaf"]:
                            
                            #Wandb
                            experiment_name = f"gbm_lr{lr}_depth{max_depth}_est{n_estimator}_loss{loss_function}_subsample{subsample}_minsplit{min_samples_split}_minleaf{min_samples_leaf}"
                            wandb.init(project="vinitoupgrade", name = experiment_name, config=hyperparameters)
                            
                            #train
                            clf = GradientBoostingClassifier(learning_rate=lr, max_depth=max_depth, n_estimators=n_estimator,
                                                             loss=loss_function, subsample=subsample, min_samples_split=min_samples_split,
                                                             min_samples_leaf=min_samples_leaf, random_state=357, validation_fraction=0.1,
                                                             n_iter_no_change=5, tol = 0.01)
                            
                            clf.fit(x_train, y_train)
                            
                            #predictions
                            y_pred = clf.predict(x_test)
                            y_pred_proba = clf.predict_proba(x_test)
                            
                            #log hyp to wandb
                            wandb.config.learning_rate = lr
                            wandb.config.max_deptth = max_depth
                            wandb.config.n_estimator = n_estimator
                            wandb.config.loss_function = loss_function
                            wandb.config.subsample = subsample
                            wandb.config.min_samples_split = min_samples_split
                            wandb.config.min_samples_leaf = min_samples_leaf
                            
                            #Calculate perfomance metrics
                            accuracy = accuracy_score(y_test, y_pred)
                            f1_macro = f1_score(y_test, y_pred, average="macro")
                            y_test_bin = label_binarize(y_test, classes=np.unique(y))
                            y_pred_bin = y_pred_proba.reshape(-1, len(np.unique(y)))
                            roc_auc_macro = roc_auc_score(y_test_bin, y_pred_bin, average="macro", multi_class="ovr")
                            
                            #log metrics wandb
                            wandb.log({"accuracy" : accuracy, "f1_macro" : f1_macro, "roc_auc_macro": roc_auc_macro, "validation_score": clf.train_score_[-1]})
                            
                            #finish
                            wandb.finish()
# Out:
# Finishing last run (ID:ngvrfq2r) before initializing another...
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
#  View run <strong style="color:#cdcd00">gbm_lr0.013_depth3_est43_lossdeviance_subsample0.8_minsplit2_minleaf1</strong> at: <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/ngvrfq2r' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/ngvrfq2r</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_105657-ngvrfq2r\logs</code>
# Successfully finished last run (ID:ngvrfq2r). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011111111111111112, max=1.0…
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>c:\Users\David\Desktop\upgrade_python\temario_bootcamp\Modulo3\Teoria\Introducción_al_ML\wandb\run-20240130_105743-63xnvokr</code>
# Syncing run <strong><a href='https://wandb.ai/doficar91/vinitoupgrade/runs/63xnvokr' target="_blank">gbm_lr0.013_depth3_est43_lossdeviance_subsample0.8_minsplit2_minleaf1</a></strong> to <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">https://wandb.ai/doficar91/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/63xnvokr' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/63xnvokr</a>
# c:\Users\David\Desktop\upgrade_python\mi_entorno\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.96296</td></tr><tr><td>f1_macro</td><td>0.96364</td></tr><tr><td>roc_auc_macro</td><td>0.99584</td></tr><tr><td>validation_score</td><td>0.45209</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.013_depth3_est43_lossdeviance_subsample0.8_minsplit2_minleaf1</strong> at: <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/63xnvokr' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/63xnvokr</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_105743-63xnvokr\logs</code>
# wandb: Currently logged in as: doficar91. Use `wandb login --relogin` to force relogin
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011277777777609622, max=1.0…
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>c:\Users\David\Desktop\upgrade_python\temario_bootcamp\Modulo3\Teoria\Introducción_al_ML\wandb\run-20240130_105754-u9lrswav</code>
# Syncing run <strong><a href='https://wandb.ai/doficar91/vinitoupgrade/runs/u9lrswav' target="_blank">gbm_lr0.013_depth3_est43_lossdeviance_subsample0.8_minsplit2_minleaf2</a></strong> to <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">https://wandb.ai/doficar91/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/u9lrswav' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/u9lrswav</a>
# c:\Users\David\Desktop\upgrade_python\mi_entorno\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.96296</td></tr><tr><td>f1_macro</td><td>0.96364</td></tr><tr><td>roc_auc_macro</td><td>0.9963</td></tr><tr><td>validation_score</td><td>0.46223</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.013_depth3_est43_lossdeviance_subsample0.8_minsplit2_minleaf2</strong> at: <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/u9lrswav' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/u9lrswav</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_105754-u9lrswav\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011277777777609622, max=1.0…
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>c:\Users\David\Desktop\upgrade_python\temario_bootcamp\Modulo3\Teoria\Introducción_al_ML\wandb\run-20240130_105801-knhtw7dj</code>
# Syncing run <strong><a href='https://wandb.ai/doficar91/vinitoupgrade/runs/knhtw7dj' target="_blank">gbm_lr0.013_depth3_est43_lossdeviance_subsample0.8_minsplit4_minleaf1</a></strong> to <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">https://wandb.ai/doficar91/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/knhtw7dj' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/knhtw7dj</a>
# c:\Users\David\Desktop\upgrade_python\mi_entorno\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.96296</td></tr><tr><td>f1_macro</td><td>0.96364</td></tr><tr><td>roc_auc_macro</td><td>0.99584</td></tr><tr><td>validation_score</td><td>0.45282</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.013_depth3_est43_lossdeviance_subsample0.8_minsplit4_minleaf1</strong> at: <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/knhtw7dj' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/knhtw7dj</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_105801-knhtw7dj\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011111111111111112, max=1.0…
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>c:\Users\David\Desktop\upgrade_python\temario_bootcamp\Modulo3\Teoria\Introducción_al_ML\wandb\run-20240130_105808-wh3l9xum</code>
# Syncing run <strong><a href='https://wandb.ai/doficar91/vinitoupgrade/runs/wh3l9xum' target="_blank">gbm_lr0.013_depth3_est43_lossdeviance_subsample0.8_minsplit4_minleaf2</a></strong> to <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">https://wandb.ai/doficar91/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/wh3l9xum' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/wh3l9xum</a>
# c:\Users\David\Desktop\upgrade_python\mi_entorno\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.96296</td></tr><tr><td>f1_macro</td><td>0.96364</td></tr><tr><td>roc_auc_macro</td><td>0.9963</td></tr><tr><td>validation_score</td><td>0.46223</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.013_depth3_est43_lossdeviance_subsample0.8_minsplit4_minleaf2</strong> at: <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/wh3l9xum' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/wh3l9xum</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_105808-wh3l9xum\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011277777777932999, max=1.0…
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>c:\Users\David\Desktop\upgrade_python\temario_bootcamp\Modulo3\Teoria\Introducción_al_ML\wandb\run-20240130_105814-8op7pn0x</code>
# Syncing run <strong><a href='https://wandb.ai/doficar91/vinitoupgrade/runs/8op7pn0x' target="_blank">gbm_lr0.013_depth3_est43_lossdeviance_subsample1.0_minsplit2_minleaf1</a></strong> to <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">https://wandb.ai/doficar91/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/8op7pn0x' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/8op7pn0x</a>
# c:\Users\David\Desktop\upgrade_python\mi_entorno\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.92593</td></tr><tr><td>f1_macro</td><td>0.92697</td></tr><tr><td>roc_auc_macro</td><td>0.9875</td></tr><tr><td>validation_score</td><td>0.44321</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.013_depth3_est43_lossdeviance_subsample1.0_minsplit2_minleaf1</strong> at: <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/8op7pn0x' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/8op7pn0x</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_105814-8op7pn0x\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011111111111111112, max=1.0…
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>c:\Users\David\Desktop\upgrade_python\temario_bootcamp\Modulo3\Teoria\Introducción_al_ML\wandb\run-20240130_105821-y0dzj4g7</code>
# Syncing run <strong><a href='https://wandb.ai/doficar91/vinitoupgrade/runs/y0dzj4g7' target="_blank">gbm_lr0.013_depth3_est43_lossdeviance_subsample1.0_minsplit2_minleaf2</a></strong> to <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">https://wandb.ai/doficar91/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/y0dzj4g7' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/y0dzj4g7</a>
# c:\Users\David\Desktop\upgrade_python\mi_entorno\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.94444</td></tr><tr><td>f1_macro</td><td>0.94677</td></tr><tr><td>roc_auc_macro</td><td>0.9853</td></tr><tr><td>validation_score</td><td>0.45679</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.013_depth3_est43_lossdeviance_subsample1.0_minsplit2_minleaf2</strong> at: <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/y0dzj4g7' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/y0dzj4g7</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_105821-y0dzj4g7\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011277777777609622, max=1.0…
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>c:\Users\David\Desktop\upgrade_python\temario_bootcamp\Modulo3\Teoria\Introducción_al_ML\wandb\run-20240130_105828-hpodc9yc</code>
# Syncing run <strong><a href='https://wandb.ai/doficar91/vinitoupgrade/runs/hpodc9yc' target="_blank">gbm_lr0.013_depth3_est43_lossdeviance_subsample1.0_minsplit4_minleaf1</a></strong> to <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">https://wandb.ai/doficar91/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/hpodc9yc' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/hpodc9yc</a>
# c:\Users\David\Desktop\upgrade_python\mi_entorno\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.92593</td></tr><tr><td>f1_macro</td><td>0.92697</td></tr><tr><td>roc_auc_macro</td><td>0.98651</td></tr><tr><td>validation_score</td><td>0.44343</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.013_depth3_est43_lossdeviance_subsample1.0_minsplit4_minleaf1</strong> at: <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/hpodc9yc' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/hpodc9yc</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_105828-hpodc9yc\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011111111111111112, max=1.0…
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>c:\Users\David\Desktop\upgrade_python\temario_bootcamp\Modulo3\Teoria\Introducción_al_ML\wandb\run-20240130_105835-y4ear3sp</code>
# Syncing run <strong><a href='https://wandb.ai/doficar91/vinitoupgrade/runs/y4ear3sp' target="_blank">gbm_lr0.013_depth3_est43_lossdeviance_subsample1.0_minsplit4_minleaf2</a></strong> to <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">https://wandb.ai/doficar91/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/y4ear3sp' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/y4ear3sp</a>
# c:\Users\David\Desktop\upgrade_python\mi_entorno\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.94444</td></tr><tr><td>f1_macro</td><td>0.94677</td></tr><tr><td>roc_auc_macro</td><td>0.9853</td></tr><tr><td>validation_score</td><td>0.45679</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.013_depth3_est43_lossdeviance_subsample1.0_minsplit4_minleaf2</strong> at: <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/y4ear3sp' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/y4ear3sp</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_105835-y4ear3sp\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011288888888925108, max=1.0…
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>c:\Users\David\Desktop\upgrade_python\temario_bootcamp\Modulo3\Teoria\Introducción_al_ML\wandb\run-20240130_105841-hvku2wa9</code>
# Syncing run <strong><a href='https://wandb.ai/doficar91/vinitoupgrade/runs/hvku2wa9' target="_blank">gbm_lr0.013_depth3_est100_lossdeviance_subsample0.8_minsplit2_minleaf1</a></strong> to <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">https://wandb.ai/doficar91/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/hvku2wa9' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/hvku2wa9</a>
# c:\Users\David\Desktop\upgrade_python\mi_entorno\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.96296</td></tr><tr><td>f1_macro</td><td>0.96364</td></tr><tr><td>roc_auc_macro</td><td>0.99537</td></tr><tr><td>validation_score</td><td>0.16631</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.013_depth3_est100_lossdeviance_subsample0.8_minsplit2_minleaf1</strong> at: <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/hvku2wa9' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/hvku2wa9</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_105841-hvku2wa9\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011288888888925108, max=1.0…
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>c:\Users\David\Desktop\upgrade_python\temario_bootcamp\Modulo3\Teoria\Introducción_al_ML\wandb\run-20240130_105848-b8sl7flt</code>
# Syncing run <strong><a href='https://wandb.ai/doficar91/vinitoupgrade/runs/b8sl7flt' target="_blank">gbm_lr0.013_depth3_est100_lossdeviance_subsample0.8_minsplit2_minleaf2</a></strong> to <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">https://wandb.ai/doficar91/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/b8sl7flt' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/b8sl7flt</a>
# c:\Users\David\Desktop\upgrade_python\mi_entorno\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.96296</td></tr><tr><td>f1_macro</td><td>0.96364</td></tr><tr><td>roc_auc_macro</td><td>0.99646</td></tr><tr><td>validation_score</td><td>0.17499</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.013_depth3_est100_lossdeviance_subsample0.8_minsplit2_minleaf2</strong> at: <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/b8sl7flt' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/b8sl7flt</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_105848-b8sl7flt\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011288888888925108, max=1.0…
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>c:\Users\David\Desktop\upgrade_python\temario_bootcamp\Modulo3\Teoria\Introducción_al_ML\wandb\run-20240130_105855-8vsv848k</code>
# Syncing run <strong><a href='https://wandb.ai/doficar91/vinitoupgrade/runs/8vsv848k' target="_blank">gbm_lr0.013_depth3_est100_lossdeviance_subsample0.8_minsplit4_minleaf1</a></strong> to <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">https://wandb.ai/doficar91/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/8vsv848k' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/8vsv848k</a>
# c:\Users\David\Desktop\upgrade_python\mi_entorno\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.96296</td></tr><tr><td>f1_macro</td><td>0.96364</td></tr><tr><td>roc_auc_macro</td><td>0.996</td></tr><tr><td>validation_score</td><td>0.16718</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.013_depth3_est100_lossdeviance_subsample0.8_minsplit4_minleaf1</strong> at: <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/8vsv848k' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/8vsv848k</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_105855-8vsv848k\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011111111111111112, max=1.0…
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>c:\Users\David\Desktop\upgrade_python\temario_bootcamp\Modulo3\Teoria\Introducción_al_ML\wandb\run-20240130_105902-m9f5m96p</code>
# Syncing run <strong><a href='https://wandb.ai/doficar91/vinitoupgrade/runs/m9f5m96p' target="_blank">gbm_lr0.013_depth3_est100_lossdeviance_subsample0.8_minsplit4_minleaf2</a></strong> to <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">https://wandb.ai/doficar91/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/m9f5m96p' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/m9f5m96p</a>
# c:\Users\David\Desktop\upgrade_python\mi_entorno\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.96296</td></tr><tr><td>f1_macro</td><td>0.96364</td></tr><tr><td>roc_auc_macro</td><td>0.99646</td></tr><tr><td>validation_score</td><td>0.17499</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.013_depth3_est100_lossdeviance_subsample0.8_minsplit4_minleaf2</strong> at: <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/m9f5m96p' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/m9f5m96p</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_105902-m9f5m96p\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011111111111111112, max=1.0…
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>c:\Users\David\Desktop\upgrade_python\temario_bootcamp\Modulo3\Teoria\Introducción_al_ML\wandb\run-20240130_105908-ztnq9bv5</code>
# Syncing run <strong><a href='https://wandb.ai/doficar91/vinitoupgrade/runs/ztnq9bv5' target="_blank">gbm_lr0.013_depth3_est100_lossdeviance_subsample1.0_minsplit2_minleaf1</a></strong> to <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">https://wandb.ai/doficar91/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/ztnq9bv5' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/ztnq9bv5</a>
# c:\Users\David\Desktop\upgrade_python\mi_entorno\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.92593</td></tr><tr><td>f1_macro</td><td>0.9276</td></tr><tr><td>roc_auc_macro</td><td>0.9875</td></tr><tr><td>validation_score</td><td>0.15639</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.013_depth3_est100_lossdeviance_subsample1.0_minsplit2_minleaf1</strong> at: <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/ztnq9bv5' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/ztnq9bv5</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_105908-ztnq9bv5\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011288888888925108, max=1.0…
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>c:\Users\David\Desktop\upgrade_python\temario_bootcamp\Modulo3\Teoria\Introducción_al_ML\wandb\run-20240130_105915-3tro5t4s</code>
# Syncing run <strong><a href='https://wandb.ai/doficar91/vinitoupgrade/runs/3tro5t4s' target="_blank">gbm_lr0.013_depth3_est100_lossdeviance_subsample1.0_minsplit2_minleaf2</a></strong> to <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">https://wandb.ai/doficar91/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/3tro5t4s' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/3tro5t4s</a>
# c:\Users\David\Desktop\upgrade_python\mi_entorno\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.94444</td></tr><tr><td>f1_macro</td><td>0.94691</td></tr><tr><td>roc_auc_macro</td><td>0.98168</td></tr><tr><td>validation_score</td><td>0.1659</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.013_depth3_est100_lossdeviance_subsample1.0_minsplit2_minleaf2</strong> at: <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/3tro5t4s' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/3tro5t4s</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_105915-3tro5t4s\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011288888888925108, max=1.0…
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>c:\Users\David\Desktop\upgrade_python\temario_bootcamp\Modulo3\Teoria\Introducción_al_ML\wandb\run-20240130_105921-tymmpht1</code>
# Syncing run <strong><a href='https://wandb.ai/doficar91/vinitoupgrade/runs/tymmpht1' target="_blank">gbm_lr0.013_depth3_est100_lossdeviance_subsample1.0_minsplit4_minleaf1</a></strong> to <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">https://wandb.ai/doficar91/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/tymmpht1' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/tymmpht1</a>
# c:\Users\David\Desktop\upgrade_python\mi_entorno\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.92593</td></tr><tr><td>f1_macro</td><td>0.9276</td></tr><tr><td>roc_auc_macro</td><td>0.98697</td></tr><tr><td>validation_score</td><td>0.15646</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.013_depth3_est100_lossdeviance_subsample1.0_minsplit4_minleaf1</strong> at: <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/tymmpht1' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/tymmpht1</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_105921-tymmpht1\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011288888888925108, max=1.0…
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>c:\Users\David\Desktop\upgrade_python\temario_bootcamp\Modulo3\Teoria\Introducción_al_ML\wandb\run-20240130_105928-qm0j7pu2</code>
# Syncing run <strong><a href='https://wandb.ai/doficar91/vinitoupgrade/runs/qm0j7pu2' target="_blank">gbm_lr0.013_depth3_est100_lossdeviance_subsample1.0_minsplit4_minleaf2</a></strong> to <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">https://wandb.ai/doficar91/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/qm0j7pu2' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/qm0j7pu2</a>
# c:\Users\David\Desktop\upgrade_python\mi_entorno\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.94444</td></tr><tr><td>f1_macro</td><td>0.94691</td></tr><tr><td>roc_auc_macro</td><td>0.98168</td></tr><tr><td>validation_score</td><td>0.1659</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.013_depth3_est100_lossdeviance_subsample1.0_minsplit4_minleaf2</strong> at: <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/qm0j7pu2' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/qm0j7pu2</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_105928-qm0j7pu2\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011277777777932999, max=1.0…
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>c:\Users\David\Desktop\upgrade_python\temario_bootcamp\Modulo3\Teoria\Introducción_al_ML\wandb\run-20240130_105935-n0to9yjp</code>
# Syncing run <strong><a href='https://wandb.ai/doficar91/vinitoupgrade/runs/n0to9yjp' target="_blank">gbm_lr0.013_depth3_est150_lossdeviance_subsample0.8_minsplit2_minleaf1</a></strong> to <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">https://wandb.ai/doficar91/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/n0to9yjp' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/n0to9yjp</a>
# c:\Users\David\Desktop\upgrade_python\mi_entorno\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.96296</td></tr><tr><td>f1_macro</td><td>0.96364</td></tr><tr><td>roc_auc_macro</td><td>0.996</td></tr><tr><td>validation_score</td><td>0.11638</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.013_depth3_est150_lossdeviance_subsample0.8_minsplit2_minleaf1</strong> at: <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/n0to9yjp' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/n0to9yjp</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_105935-n0to9yjp\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011277777777609622, max=1.0…
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>c:\Users\David\Desktop\upgrade_python\temario_bootcamp\Modulo3\Teoria\Introducción_al_ML\wandb\run-20240130_105941-fq9ynj5u</code>
# Syncing run <strong><a href='https://wandb.ai/doficar91/vinitoupgrade/runs/fq9ynj5u' target="_blank">gbm_lr0.013_depth3_est150_lossdeviance_subsample0.8_minsplit2_minleaf2</a></strong> to <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
# ...
# Syncing run <strong><a href='https://wandb.ai/doficar91/vinitoupgrade/runs/eyo497qg' target="_blank">gbm_lr0.6_depth6_est150_lossdeviance_subsample0.8_minsplit4_minleaf1</a></strong> to <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">https://wandb.ai/doficar91/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/eyo497qg' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/eyo497qg</a>
# c:\Users\David\Desktop\upgrade_python\mi_entorno\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.94444</td></tr><tr><td>f1_macro</td><td>0.94691</td></tr><tr><td>roc_auc_macro</td><td>0.99699</td></tr><tr><td>validation_score</td><td>0.00015</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.6_depth6_est150_lossdeviance_subsample0.8_minsplit4_minleaf1</strong> at: <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/eyo497qg' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/eyo497qg</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_114112-eyo497qg\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011277777777932999, max=1.0…
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>c:\Users\David\Desktop\upgrade_python\temario_bootcamp\Modulo3\Teoria\Introducción_al_ML\wandb\run-20240130_114119-x5n600ky</code>
# Syncing run <strong><a href='https://wandb.ai/doficar91/vinitoupgrade/runs/x5n600ky' target="_blank">gbm_lr0.6_depth6_est150_lossdeviance_subsample0.8_minsplit4_minleaf2</a></strong> to <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">https://wandb.ai/doficar91/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/x5n600ky' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/x5n600ky</a>
# c:\Users\David\Desktop\upgrade_python\mi_entorno\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.96296</td></tr><tr><td>f1_macro</td><td>0.96364</td></tr><tr><td>roc_auc_macro</td><td>0.99901</td></tr><tr><td>validation_score</td><td>5e-05</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.6_depth6_est150_lossdeviance_subsample0.8_minsplit4_minleaf2</strong> at: <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/x5n600ky' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/x5n600ky</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_114119-x5n600ky\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011455555555746995, max=1.0…
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>c:\Users\David\Desktop\upgrade_python\temario_bootcamp\Modulo3\Teoria\Introducción_al_ML\wandb\run-20240130_114126-kbnnm7n5</code>
# Syncing run <strong><a href='https://wandb.ai/doficar91/vinitoupgrade/runs/kbnnm7n5' target="_blank">gbm_lr0.6_depth6_est150_lossdeviance_subsample1.0_minsplit2_minleaf1</a></strong> to <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">https://wandb.ai/doficar91/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/kbnnm7n5' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/kbnnm7n5</a>
# c:\Users\David\Desktop\upgrade_python\mi_entorno\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.92593</td></tr><tr><td>f1_macro</td><td>0.92737</td></tr><tr><td>roc_auc_macro</td><td>0.98264</td></tr><tr><td>validation_score</td><td>8e-05</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.6_depth6_est150_lossdeviance_subsample1.0_minsplit2_minleaf1</strong> at: <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/kbnnm7n5' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/kbnnm7n5</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_114126-kbnnm7n5\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011111111111111112, max=1.0…
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>c:\Users\David\Desktop\upgrade_python\temario_bootcamp\Modulo3\Teoria\Introducción_al_ML\wandb\run-20240130_114133-rzcjvsdn</code>
# Syncing run <strong><a href='https://wandb.ai/doficar91/vinitoupgrade/runs/rzcjvsdn' target="_blank">gbm_lr0.6_depth6_est150_lossdeviance_subsample1.0_minsplit2_minleaf2</a></strong> to <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">https://wandb.ai/doficar91/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/rzcjvsdn' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/rzcjvsdn</a>
# c:\Users\David\Desktop\upgrade_python\mi_entorno\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.98148</td></tr><tr><td>f1_macro</td><td>0.98056</td></tr><tr><td>roc_auc_macro</td><td>0.98217</td></tr><tr><td>validation_score</td><td>0.0001</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.6_depth6_est150_lossdeviance_subsample1.0_minsplit2_minleaf2</strong> at: <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/rzcjvsdn' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/rzcjvsdn</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_114133-rzcjvsdn\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011111111111111112, max=1.0…
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>c:\Users\David\Desktop\upgrade_python\temario_bootcamp\Modulo3\Teoria\Introducción_al_ML\wandb\run-20240130_114139-gly0khv6</code>
# Syncing run <strong><a href='https://wandb.ai/doficar91/vinitoupgrade/runs/gly0khv6' target="_blank">gbm_lr0.6_depth6_est150_lossdeviance_subsample1.0_minsplit4_minleaf1</a></strong> to <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">https://wandb.ai/doficar91/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/gly0khv6' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/gly0khv6</a>
# c:\Users\David\Desktop\upgrade_python\mi_entorno\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.94444</td></tr><tr><td>f1_macro</td><td>0.94444</td></tr><tr><td>roc_auc_macro</td><td>0.98389</td></tr><tr><td>validation_score</td><td>8e-05</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.6_depth6_est150_lossdeviance_subsample1.0_minsplit4_minleaf1</strong> at: <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/gly0khv6' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/gly0khv6</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_114139-gly0khv6\logs</code>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01128888888860173, max=1.0)…
# wandb version 0.16.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>c:\Users\David\Desktop\upgrade_python\temario_bootcamp\Modulo3\Teoria\Introducción_al_ML\wandb\run-20240130_114146-zitz56dx</code>
# Syncing run <strong><a href='https://wandb.ai/doficar91/vinitoupgrade/runs/zitz56dx' target="_blank">gbm_lr0.6_depth6_est150_lossdeviance_subsample1.0_minsplit4_minleaf2</a></strong> to <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/doficar91/vinitoupgrade' target="_blank">https://wandb.ai/doficar91/vinitoupgrade</a>
#  View run at <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/zitz56dx' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/zitz56dx</a>
# c:\Users\David\Desktop\upgrade_python\mi_entorno\lib\site-packages\sklearn\ensemble\_gb.py:280: FutureWarning: The loss parameter name 'deviance' was deprecated in v1.1 and will be removed in version 1.3. Use the new parameter name 'log_loss' which is equivalent.
#   warnings.warn(
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr><tr><td>f1_macro</td><td>▁</td></tr><tr><td>roc_auc_macro</td><td>▁</td></tr><tr><td>validation_score</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.98148</td></tr><tr><td>f1_macro</td><td>0.98056</td></tr><tr><td>roc_auc_macro</td><td>0.98217</td></tr><tr><td>validation_score</td><td>0.0001</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gbm_lr0.6_depth6_est150_lossdeviance_subsample1.0_minsplit4_minleaf2</strong> at: <a href='https://wandb.ai/doficar91/vinitoupgrade/runs/zitz56dx' target="_blank">https://wandb.ai/doficar91/vinitoupgrade/runs/zitz56dx</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240130_114146-zitz56dx\logs</code>
